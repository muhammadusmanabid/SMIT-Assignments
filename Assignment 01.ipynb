# %% [markdown]
# # Write a Python program to print "Hello, Python!".

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# ## Print your full name on one line.

# %%
print("Muhammad Usman")
# Out:
# Muhammad Usman

# %% [markdown]
# ## Print the following text exactly as shown:
#
# Python is fun!
#
# Let's start learning.

# %%
print("Python is fun! \n")
print("Let's start learning.")
# Out:
# Python is fun!
#
# Let's start learning.

# %% [markdown]
# ## Print three numbers: 5, 10, and 15 on the same line separated by spaces

# %%
print(5, 10, 15)
# Out:
# 5 10 15

# %% [markdown]
# ## Print your name five times, each on a new line using one print() statement.

# %%
print("Muhammad Usman", "Muhammad Usman", "Muhammad Usman", "Muhammad Usman", "Muhammad Usman", sep = "\n")
# Out:
# Muhammad Usman
# Muhammad Usman
# Muhammad Usman
# Muhammad Usman
# Muhammad Usman

# %% [markdown]
# ## Write a program to display the type of these values:
#
# * 45
#
# * 4.5
#
# * 'Python'
#
# * True

# %%
print(type(45))
print(type(4.5))
print(type('Python'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Check and print the type of the result when you add an integer (5) and a float (2.5)

# %%
print(type(5))
print(type(2.5))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## Write a program to add two numbers: 12 and 8.

# %%
print(12 + 8)
# Out:
# 20

# %% [markdown]
# ## Subtract 7 from 15 and display the result

# %%
print(7 - 15)
# Out:
# -8

# %% [markdown]
# ## Multiply 6 by 4 and display the result.

# %%
print(6 * 4)
# Out:
# 24

# %% [markdown]
# ## Divide 20 by 3 and display the result

# %%
print(20 / 3)
# Out:
# 6.666666666666667

# %% [markdown]
# ## Use floor division to find how many full times 20 fits into 3.

# %%
print(20 // 3)
# Out:
# 6

# %% [markdown]
# ## Find the remainder when 22 is divided by 5.

# %%
print(22 % 5)
# Out:
# 2

# %% [markdown]
# ## Write a program to check if 10 is equal to 10 using ==.

# %%
10 == 10
# Out:
# True

# %% [markdown]
# ## Compare two numbers, 8 and 12, to see if they are not equal using !=

# %%
8 != 12
# Out:
# True

# %% [markdown]
# ## Check if 15 is greater than 9

# %%
15 > 9
# Out:
# True

# %% [markdown]
# ## Verify if 7 is less than 5

# %%
7 < 5
# Out:
# False

# %% [markdown]
# ## Test if 20 is greater than or equal to 20

# %%
20 >= 20
# Out:
# True

# %% [markdown]
# ## Test if 13 is less than or equal to 15

# %%
13 <= 15
# Out:
# True
