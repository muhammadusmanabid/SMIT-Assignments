# %% [markdown]
# # Write a program that Prints your name and favorite hobby using print()

# %%
print("Name: Muhammad Usman", "|" ,"Hobbies: Learning and Watching Movies")
# Out:
# Name: Muhammad Usman | Hobbies: Learning and Watching Movies

# %% [markdown]
# # Create a variable called sentence and store this text:
# "Python programming is fun"
# * Use len() to find how many characters are in the string.
#
# * Print the result.

# %%
sentence = "Python Programming is fun"
print(sentence, "|", "Length of sentence:", len(sentence))
# Out:
# Python Programming is fun | Length of sentence: 25

# %% [markdown]
# # Store the string "PYTHON" in a variable called word.
#
# ### Write code to print:
#
# * The first character.
#
# * The last character.
#
# * The character at index 3.

# %%
word = "PYTHON"
print("First Character is", word[0])
print("Last Character is", word[5])
print("Character at Index 3 is", word[3])
# Out:
# First Character is P
# Last Character is N
# Character at Index 3 is H

# %% [markdown]
# # Using the same string "PYTHON":
#
# * Slice and print "PYT".
#
# * Slice and print "HON".
#
# * Slice and print "PTO"

# %%
word = "PYTHON"
print(word[0:3])
print(word[3:6])
print(word[0:1],word[2:3],word[4:5])
# Out:
# PYT
# HON
# P T O

# %% [markdown]
# # Given the string "HELLO", print the first, third, and last characters

# %%
string = "HELLO"
print("First Character is", string[0])
print("Third Character is", string[2])
print("Last Character is", string[4])
# Out:
# First Character is H
# Third Character is L
# Last Character is O

# %% [markdown]
# # Store your favorite fruit name in a variable. Print how many characters it has.

# %%
fruit = "kiwi"
print(len(fruit))
# Out:
# 4

# %% [markdown]
# # Write a program that takes the string "PYTHON" and prints the character at index 2 and index 4.

# %%
string = input("Enter a string: ")
print(string[2])
print(string[4])
# Out:
# T
# O

# %% [markdown]
# # Write a program that asks the user to enter a word and then prints the first 4 characters

# %%
word = input("Enter a string: ")
print("User entry is:", word)
print(word[0:4])
# Out:
# User entry is: python
# pyth

# %% [markdown]
# # Store the string "i love python" in a variable and print it in uppercase

# %%
word = "I love Python"
print(word.upper())
# Out:
# I LOVE PYTHON

# %% [markdown]
# # Store "I LOVE CODING" in a variable and print it in lowercase

# %%
word = "I LOVE CODING"
print(word.lower())
# Out:
# i love coding

# %% [markdown]
# # Store "python is fun" in a variable and print it with only the first letter capitalized.

# %%
word = "python is fun"
print(word.capitalize())
# Out:
# Python is fun

# %% [markdown]
# # Store your age in a variable and print its type using type().

# %%
age = 19
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# # Write a program that subtracts two numbers and prints the result.

# %%
num1 = 10
num2 = 2
result = num1 - num2
print("Result:", result)
# Out:
# Result: 8

# %% [markdown]
# # Write a program that adds two numbers and prints the result.

# %%
num1 = 10
num2 = 2
result = num1 + num2
print("Result:", result)
# Out:
# Result: 12

# %% [markdown]
# # Write a program that multiplies two numbers and prints the result.

# %%
num1 = 10
num2 = 2
result = num1 * num2
print("Result:", result)
# Out:
# Result: 20

# %% [markdown]
# ## Given "PYTHONPROGRAMMING", print every second character

# %%
word = "PYTHONPROGRAMMING"
print(word[::2])
# Out:
# PTOPORMIG

# %% [markdown]
# # Print every third character from "PYTHONPROGRAMMING"

# %%
word = "PYTHONPROGRAMMING"
print(word[::3])
# Out:
# PHPGMN

# %% [markdown]
# ## Reverse the string "HELLOWORLD"

# %%
text = "HELLOWORLD"
print(text[::-1])
# Out:
# DLROWOLLEH

# %% [markdown]
# # Print only the even-indexed characters from "DATASCIENCE"

# %%
text = "DATASCIENCE"
print(text[::2])
# Out:
# DTSINE

# %% [markdown]
# # Print only the odd-indexed characters from "PROGRAMMER"

# %%
text = "PROGRAMMER"
print(text[::3])
# Out:
# PGMR

# %% [markdown]
# # From "ABCDEFGHIJKL", print characters between index 2 and 10 with step 2

# %%
text = "ABCDEFGHIJKL"
print(text[2:10:2])
# Out:
# CEGI

# %% [markdown]
# # From "ABCDEFGHIJKL", print characters between index 1 and 9 with step 3

# %%
text = "ABCDEFGHIJKL"
print(text[1:9:3])
# Out:
# BEH

# %% [markdown]
# # From "HELLOWORLD", print the first 5 characters in reverse order

# %%
text = "HELLOWORLD"
print(text[:5][::-1])
# Out:
# OLLEH

# %% [markdown]
# # From "HELLOWORLD", print the substring "WORLD" in reverse

# %%
text = "HELLOWORLD"
print(text[5:10][::-1])
# Out:
# DLROW

# %% [markdown]
# # From "PYTHONPROGRAMMING", print characters from index 5 to end in reverse order

# %%
text = "PYTHONPROGRAMMING"
print(text[5:17][::-1])
# Out:
# GNIMMARGORPN

# %% [markdown]
# # Store your first name and last name in two variables and print the full name u

# %%
first_name = "Muhammad"
last_name = " Usman"
print(first_name + last_name)
# Out:
# Muhammad Usman

# %% [markdown]
# # Print "Python" three times

# %%
word = " Python"
text = word * 3
print(text)
# Out:
#  Python Python Python

# %% [markdown]
# # Print "Hello " and "World!" with a space in between using +

# %%
a = "Hello"
b = "World!"
print(a + b)
# Out:
# HelloWorld!

# %% [markdown]
# # Store two strings "Data" and "Science" and join them into "DataScience"

# %%
str_1 = "Data"
str_2 = "Science"
print(str_1 + str_2)
# Out:
# DataScience

# %% [markdown]
# # Print the string "Hi!" 10 times, each on a new line

# %%
text = "Hi!"
word = text * 10
print(word,"\n")
# Out:
# Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!Hi!

# %% [markdown]
# # Print a pattern: "-*-" repeated 8 times

# %%
word = "-*-"
pattern = word * 8
print(pattern)
# Out:
# -*--*--*--*--*--*--*--*-
